# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt
import requests

# %%
# getting csv files from the folder MyProject
path = "./data/"

panj = pd.read_csv(r'./data/long.txt')

# %%
panj = panj[['DateTime','A']]

# %%
from datetime import datetime

# %%
panj.iloc[[0, -1]].head()
# Out:
#                DateTime       A
# 0       8/12/2017 11:00  4.3171
# 645901   2/03/2019 0:01  7.3413

# %%
panj.plot(y='A', use_index=True)
# Out:
# <Axes: >

# %%
panj = panj.iloc[:43982]

# %%
print(panj)
# Out:
#               DateTime       A
# 0      8/12/2017 11:00  4.3171
# 1      8/12/2017 11:01  4.3165
# 2      8/12/2017 11:02  4.3156
# 3      8/12/2017 11:03  4.3159
# 4      8/12/2017 11:04  4.3159
# ...                ...     ...
# 43977  7/01/2018 23:57  4.4568
# 43978  7/01/2018 23:58  4.4568
# 43979  7/01/2018 23:59  4.4568
# 43980   8/01/2018 0:00  4.4568
# 43981   8/01/2018 0:01  4.4553
#
# [43982 rows x 2 columns]

# %%
panj.plot(y='A', use_index=True)
# Out:
# <Axes: >

# %%
panj = panj.iloc[:1400]
print(panj)
panj.plot(y='A', use_index=True)
# Out:
#              DateTime       A
# 0     8/12/2017 11:00  4.3171
# 1     8/12/2017 11:01  4.3165
# 2     8/12/2017 11:02  4.3156
# 3     8/12/2017 11:03  4.3159
# 4     8/12/2017 11:04  4.3159
# ...               ...     ...
# 1395  9/12/2017 10:15  4.3119
# 1396  9/12/2017 10:16  4.3119
# 1397  9/12/2017 10:17  4.3128
# 1398  9/12/2017 10:18  4.3122
# 1399  9/12/2017 10:19  4.3122
#
# [1400 rows x 2 columns]
# <Axes: >

# %%
panj.iloc[[0,600,1000,1399]].head()
# Out:
#              DateTime       A
# 0     8/12/2017 11:00  4.3171
# 600   8/12/2017 21:00  4.3141
# 1000   9/12/2017 3:40  4.3134
# 1399  9/12/2017 10:19  4.3122
